# %% [markdown]
# # 데이터 분석 시험지 6 — exercise (운동과 맥박)  · 학생용
#
# > ✍️ **여기를 더블클릭**한 뒤, 아랫줄에 학년·반·번호·이름을 입력하세요.
# >
# > 학년: 　　 반: 　　 번호: 　　 이름:
#
# > 📌 데이터프레임은 반드시 **`testdf`** 로 저장하세요. 코드는 **참고파일(펭귄 예시 코드)**을 참고해 작성합니다.

# %% [markdown]
# ## ⚙️ 준비 셀 — 시험 시작 전 **한 번만 실행**하세요
#
# > 아래 셀을 실행하고 `준비 완료! ✅` 가 나오면 1번부터 시작합니다. (처음 실행은 10~20초 걸릴 수 있어요)

# %%
import micropip
await micropip.install(["pyodide-http", "seaborn"])
import pyodide_http
pyodide_http.patch_all()
print("준비 완료! ✅")

# %% [markdown]
# ## 📖 데이터셋 소개 — exercise (운동과 맥박)
#
# **운동 실험**에 참가한 사람 30명의 맥박을 잰 데이터입니다.
# 참가자는 휴식/걷기/달리기 중 하나를 했고, 1분·15분·30분 시점에 맥박을 쟀어요.
# (30명 × 3번 측정 = 90개 기록)
#
# | 열 이름 | 의미 |
# |---|---|
# | `id` | 참가자 번호 |
# | `diet` | 식단 유형 — low fat(저지방) / no fat(무지방) |
# | `pulse` | 맥박 수 (1분당 심장 박동 수) |
# | `time` | 측정 시점 — 1 min / 15 min / 30 min |
# | `kind` | 활동 종류 — rest(휴식) / walking(걷기) / running(달리기) |

# %% [markdown]
# ## 1. 데이터 준비
#
# `exercise` 데이터를 불러와 **`testdf`** 로 저장하고, **결측치가 있으면 삭제**하시오.
#
# 데이터 불러오기 코드:
# ```python
# sns.load_dataset("exercise")
# ```

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 2. 데이터 확인
#
# 앞부분 5행을 출력하시오. (`head()`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 3. 통계값
#
# 수치형 요약 통계를 보시오. (`describe()`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 4. 데이터 크기
#
# 데이터의 (행, 열) 크기를 확인하시오. (`shape`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 5. 기본 그래프 🎨
#
# 맥박(`pulse`)의 **히스토그램**을 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Pulse distribution`
# - x축 라벨: `pulse` / y축 라벨: `count`
# - 컬러: **`crimson`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 6. 심화 그래프 (groupby) 🎨
#
# 운동 종류(`kind`)별 **평균 맥박(`pulse`)**을 **막대그래프**로 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Mean pulse by kind`
# - x축 라벨: `kind` / y축 라벨: `mean pulse`
# - 컬러: **`yellowgreen`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 7. 그래프 분석
#
# 위 **기본·심화 그래프**를 보고 알 수 있는 점을 **2문장**으로 쓰시오.

# %% [markdown]
# ✏️ **답:** (여기를 더블클릭해 2문장으로 작성하세요)
