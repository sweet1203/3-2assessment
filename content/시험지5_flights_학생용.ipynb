# %% [markdown]
# # 데이터 분석 시험지 5 — flights (항공 승객)  · 학생용
#
# > ✍️ **여기를 더블클릭**한 뒤, 아랫줄에 학년·반·번호·이름을 입력하세요.
# >
# > 학년: 　　 반: 　　 번호: 　　 이름:
#
# > 📌 데이터프레임은 반드시 **`testdf`** 로 저장하세요. 코드는 **참고파일(펭귄 예시 코드)**을 참고해 작성합니다.

# %% [markdown]
# ## ⚙️ 시험을 위한 준비 — 시작 전 **한 번만 실행**하세요
#
# > 이 셀은 **시험 환경을 준비하는 코드**입니다(채점과 무관합니다).
# > 실행 후 `준비 완료! ✅` 가 나오면 **1번 문제**부터 시작하세요. (처음 실행은 10~20초 걸릴 수 있어요)

# %%
import micropip
await micropip.install(["pyodide-http", "seaborn"])
import pyodide_http
pyodide_http.patch_all()

import warnings
warnings.filterwarnings("ignore")   # 경고 메시지 숨김 (시험 중 혼란 방지)

print("준비 완료! ✅")

# %% [markdown]
# ## 📖 데이터셋 소개 — flights (항공 승객)
#
# 1949년부터 1960년까지 **12년간 매달 비행기를 탄 승객 수**를 기록한 데이터입니다.
# 12년 × 12개월 = 144개의 월별 기록으로, 항공 여행이 얼마나 빠르게 성장했는지 보여줘요.
# (승객 수 단위: 천 명 — 예: 112면 약 11만 2천 명)
#
# | 열 이름 | 의미 |
# |---|---|
# | `year` | 연도 (1949~1960) |
# | `month` | 월 (Jan~Dec) |
# | `passengers` | 그 달의 승객 수 (천 명) |

# %% [markdown]
# ## 1. 데이터 준비
#
# ① 파이썬 데이터 분석에 필요한 **라이브러리 3개**를 불러오시오.
#
# ② 아래 코드를 참고하여 `flights` 데이터를 불러와 **`testdf`** 로 저장하시오.
#
# ```python
# sns.load_dataset("flights")
# ```
#
# ③ **결측치가 있으면 삭제**하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 2. 데이터 확인
#
# 데이터의 **앞부분 5행**을 출력하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 3. 통계값
#
# 수치형 열의 **요약 통계**를 출력하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 4. 데이터 크기
#
# 데이터의 **(행, 열) 크기**를 출력하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 5. 기본 그래프 🎨
#
# 월별 승객 수(`passengers`)의 **히스토그램**을 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Passengers distribution`
# - x축 라벨: `passengers` / y축 라벨: `count`
# - 컬러: **`mediumpurple`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 6. 심화 그래프 (groupby) 🎨
#
# 연도(`year`)별 **평균 승객 수(`passengers`)**를 **막대그래프**로 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Mean passengers by year`
# - x축 라벨: `year` / y축 라벨: `mean passengers`
# - 컬러: **`turquoise`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 7. 그래프 분석
#
# 위 **기본·심화 그래프**를 보고 알 수 있는 점을 **2문장**으로 쓰시오.

# %% [markdown]
# ✏️ **답:** (여기를 더블클릭해 2문장으로 작성하세요)
