# %% [markdown]
# # 데이터 분석 시험지 1 — tips (식당 팁)  · 학생용
#
# > ✍️ **여기를 더블클릭**한 뒤, 아랫줄에 학년·반·번호·이름을 입력하세요.
# >
# > 학년: 　　 반: 　　 번호: 　　 이름:
#
# > 📌 데이터프레임은 반드시 **`testdf`** 로 저장하세요. 코드는 **참고파일(펭귄 예시 코드)**을 참고해 작성합니다.

# %% [markdown]
# ## ⚙️ 준비 셀 — 시험 시작 전 **한 번만 실행**하세요
#
# > 아래 셀을 실행하고 `준비 완료! ✅` 가 나오면 1번부터 시작합니다. (처음 실행은 10~20초 걸릴 수 있어요)

# %%
import micropip
await micropip.install(["pyodide-http", "seaborn"])
import pyodide_http
pyodide_http.patch_all()
print("준비 완료! ✅")

# %% [markdown]
# ## 📖 데이터셋 소개 — tips (식당 팁)
#
# 미국의 한 식당에서 **손님 244팀의 계산 기록**을 모은 데이터입니다.
# 웨이터가 일하면서 "어떤 손님이 팁을 얼마나 주는지" 기록했어요.
#
# | 열 이름 | 의미 |
# |---|---|
# | `total_bill` | 식사 금액 (달러) |
# | `tip` | 손님이 준 팁 (달러) |
# | `sex` | 계산한 손님의 성별 (Male/Female) |
# | `smoker` | 흡연석 여부 (Yes/No) |
# | `day` | 요일 (Thur/Fri/Sat/Sun) |
# | `time` | 점심(Lunch)인지 저녁(Dinner)인지 |
# | `size` | 일행 수 (몇 명이 함께 왔는지) |

# %% [markdown]
# ## 1. 데이터 준비
#
# `tips` 데이터를 불러와 **`testdf`** 로 저장하고, **결측치가 있으면 삭제**하시오.
#
# 데이터 불러오기 코드:
# ```python
# sns.load_dataset("tips")
# ```

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 2. 데이터 확인
#
# 앞부분 5행을 출력하시오. (`head()`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 3. 통계값
#
# 수치형 요약 통계를 보시오. (`describe()`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 4. 데이터 크기
#
# 데이터의 (행, 열) 크기를 확인하시오. (`shape`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 5. 기본 그래프 🎨
#
# 결제금액(`total_bill`)과 팁(`tip`)의 **산점도**를 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Total bill vs tip`
# - x축 라벨: `total_bill` / y축 라벨: `tip`
# - 컬러: **`salmon`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 6. 심화 그래프 (groupby) 🎨
#
# 요일(`day`)별 **평균 팁(`tip`)**을 **막대그래프**로 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Mean tip by day`
# - x축 라벨: `day` / y축 라벨: `mean tip`
# - 컬러: **`gold`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 7. 그래프 분석
#
# 위 **기본·심화 그래프**를 보고 알 수 있는 점을 **2문장**으로 쓰시오.

# %% [markdown]
# ✏️ **답:** (여기를 더블클릭해 2문장으로 작성하세요)
