# %% [markdown]
# # 데이터 분석 시험지 4 — geyser (간헐천 분출)  · 학생용
#
# > ✍️ **여기를 더블클릭**한 뒤, 아랫줄에 학년·반·번호·이름을 입력하세요.
# >
# > 학년: 　　 반: 　　 번호: 　　 이름:
#
# > 📌 데이터프레임은 반드시 **`testdf`** 로 저장하세요. 코드는 **참고파일(펭귄 예시 코드)**을 참고해 작성합니다.

# %% [markdown]
# ## ⚙️ 준비 셀 — 시험 시작 전 **한 번만 실행**하세요
#
# > 아래 셀을 실행하고 `준비 완료! ✅` 가 나오면 1번부터 시작합니다. (처음 실행은 10~20초 걸릴 수 있어요)

# %%
import micropip
await micropip.install(["pyodide-http", "seaborn"])
import pyodide_http
pyodide_http.patch_all()

import warnings
warnings.filterwarnings("ignore")   # 경고 메시지 숨김 (시험 중 혼란 방지)

print("준비 완료! ✅")

# %% [markdown]
# ## 📖 데이터셋 소개 — geyser (간헐천 분출)
#
# 미국 옐로스톤 국립공원의 유명한 간헐천 **"올드 페이스풀(Old Faithful)"** 을 관찰한 기록입니다.
# 간헐천은 뜨거운 물이 주기적으로 솟구치는 온천인데, **272번의 분출**을 지켜보며
# "몇 분 동안 뿜었는지"와 "다음 분출까지 얼마나 기다렸는지"를 기록했어요.
#
# | 열 이름 | 의미 |
# |---|---|
# | `duration` | 분출이 지속된 시간 (분) |
# | `waiting` | 다음 분출까지 기다린 시간 (분) |
# | `kind` | 분출 유형 — long(긴 분출) / short(짧은 분출) |

# %% [markdown]
# ## 1. 데이터 준비
#
# `geyser` 데이터를 불러와 **`testdf`** 로 저장하고, **결측치가 있으면 삭제**하시오.
#
# 데이터 불러오기 코드:
# ```python
# sns.load_dataset("geyser")
# ```

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 2. 데이터 확인
#
# 앞부분 5행을 출력하시오. (`head()`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 3. 통계값
#
# 수치형 요약 통계를 보시오. (`describe()`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 4. 데이터 크기
#
# 데이터의 (행, 열) 크기를 확인하시오. (`shape`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 5. 기본 그래프 🎨
#
# 분출 지속시간(`duration`)과 다음 분출까지 대기시간(`waiting`)의 **산점도**를 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Duration vs waiting`
# - x축 라벨: `duration` / y축 라벨: `waiting`
# - 컬러: **`skyblue`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 6. 심화 그래프 (groupby) 🎨
#
# 분출 유형(`kind`)별 **평균 대기시간(`waiting`)**을 **막대그래프**로 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Mean waiting by kind`
# - x축 라벨: `kind` / y축 라벨: `mean waiting`
# - 컬러: **`plum`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 7. 그래프 분석
#
# 위 **기본·심화 그래프**를 보고 알 수 있는 점을 **2문장**으로 쓰시오.

# %% [markdown]
# ✏️ **답:** (여기를 더블클릭해 2문장으로 작성하세요)
