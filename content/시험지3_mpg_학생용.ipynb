# %% [markdown]
# # 데이터 분석 시험지 3 — mpg (자동차 연비)  · 학생용
#
# > ✍️ **여기를 더블클릭**한 뒤, 아랫줄에 학년·반·번호·이름을 입력하세요.
# >
# > 학년: 　　 반: 　　 번호: 　　 이름:
#
# > 📌 데이터프레임은 반드시 **`testdf`** 로 저장하세요. 코드는 **참고파일(펭귄 예시 코드)**을 참고해 작성합니다.

# %% [markdown]
# ## ⚙️ 준비 셀 — 시험 시작 전 **한 번만 실행**하세요
#
# > 아래 셀을 실행하고 `준비 완료! ✅` 가 나오면 1번부터 시작합니다. (처음 실행은 10~20초 걸릴 수 있어요)

# %%
import micropip
await micropip.install(["pyodide-http", "seaborn"])
import pyodide_http
pyodide_http.patch_all()

import warnings
warnings.filterwarnings("ignore")   # 경고 메시지 숨김 (시험 중 혼란 방지)

print("준비 완료! ✅")

# %% [markdown]
# ## 📖 데이터셋 소개 — mpg (자동차 연비)
#
# 1970~1982년에 판매된 **자동차 398대의 성능 기록**입니다.
# "어떤 차가 기름을 적게 먹는지" 비교하려고 차의 무게·엔진·연비를 모았어요.
# (mpg = miles per gallon, 연료 1갤런으로 몇 마일을 가는지 → 클수록 연비가 좋음)
#
# | 열 이름 | 의미 |
# |---|---|
# | `mpg` | 연비 (클수록 기름을 적게 먹음) |
# | `cylinders` | 엔진 실린더 수 |
# | `displacement` | 엔진 배기량 |
# | `horsepower` | 마력 (엔진 힘) |
# | `weight` | 차 무게 (파운드) |
# | `acceleration` | 가속 성능 |
# | `model_year` | 출시 연도 (70=1970년) |
# | `origin` | 제조국 — usa / europe / japan |
# | `name` | 차 이름 |

# %% [markdown]
# ## 1. 데이터 준비
#
# `mpg` 데이터를 불러와 **`testdf`** 로 저장하고, **결측치가 있으면 삭제**하시오.
#
# 데이터 불러오기 코드:
# ```python
# sns.load_dataset("mpg")
# ```

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 2. 데이터 확인
#
# 앞부분 5행을 출력하시오. (`head()`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 3. 통계값
#
# 수치형 요약 통계를 보시오. (`describe()`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 4. 데이터 크기
#
# 데이터의 (행, 열) 크기를 확인하시오. (`shape`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 5. 기본 그래프 🎨
#
# 무게(`weight`)와 연비(`mpg`)의 **산점도**를 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Weight vs mpg`
# - x축 라벨: `weight` / y축 라벨: `mpg`
# - 컬러: **`coral`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 6. 심화 그래프 (groupby) 🎨
#
# 제조국(`origin`)별 **평균 연비(`mpg`)**를 **막대그래프**로 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Mean mpg by origin`
# - x축 라벨: `origin` / y축 라벨: `mean mpg`
# - 컬러: **`steelblue`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 7. 그래프 분석
#
# 위 **기본·심화 그래프**를 보고 알 수 있는 점을 **2문장**으로 쓰시오.

# %% [markdown]
# ✏️ **답:** (여기를 더블클릭해 2문장으로 작성하세요)
