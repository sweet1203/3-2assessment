# %% [markdown]
# # 데이터 분석 시험지 2 — iris (붓꽃)  · 학생용
#
# > ✍️ **여기를 더블클릭**한 뒤, 아랫줄에 학년·반·번호·이름을 입력하세요.
# >
# > 학년: 　　 반: 　　 번호: 　　 이름:
#
# > 📌 데이터프레임은 반드시 **`testdf`** 로 저장하세요. 코드는 **참고파일(펭귄 예시 코드)**을 참고해 작성합니다.

# %% [markdown]
# ## ⚙️ 준비 셀 — 시험 시작 전 **한 번만 실행**하세요
#
# > 아래 셀을 실행하고 `준비 완료! ✅` 가 나오면 1번부터 시작합니다. (처음 실행은 10~20초 걸릴 수 있어요)

# %%
import micropip
await micropip.install(["pyodide-http", "seaborn"])
import pyodide_http
pyodide_http.patch_all()

import warnings
warnings.filterwarnings("ignore")   # 경고 메시지 숨김 (시험 중 혼란 방지)

print("준비 완료! ✅")

# %% [markdown]
# ## 📖 데이터셋 소개 — iris (붓꽃)
#
# 식물학자가 **붓꽃 150송이**를 채집해 꽃의 크기를 자로 잰 데이터입니다.
# 세 가지 품종의 꽃받침과 꽃잎 크기를 측정했어요. (1936년부터 쓰인 가장 유명한 연습 데이터!)
#
# | 열 이름 | 의미 |
# |---|---|
# | `sepal_length` | 꽃받침 길이 (cm) |
# | `sepal_width` | 꽃받침 너비 (cm) |
# | `petal_length` | 꽃잎 길이 (cm) |
# | `petal_width` | 꽃잎 너비 (cm) |
# | `species` | 품종 — setosa / versicolor / virginica |

# %% [markdown]
# ## 1. 데이터 준비
#
# `iris` 데이터를 불러와 **`testdf`** 로 저장하고, **결측치가 있으면 삭제**하시오.
#
# 데이터 불러오기 코드:
# ```python
# sns.load_dataset("iris")
# ```

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 2. 데이터 확인
#
# 앞부분 5행을 출력하시오. (`head()`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 3. 통계값
#
# 수치형 요약 통계를 보시오. (`describe()`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 4. 데이터 크기
#
# 데이터의 (행, 열) 크기를 확인하시오. (`shape`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 5. 기본 그래프 🎨
#
# 꽃잎 길이(`petal_length`)와 너비(`petal_width`)의 **산점도**를 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Petal length vs width`
# - x축 라벨: `petal_length` / y축 라벨: `petal_width`
# - 컬러: **`mediumseagreen`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 6. 심화 그래프 (groupby) 🎨
#
# 종(`species`)별 **평균 꽃잎 길이(`petal_length`)**를 **막대그래프**로 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Mean petal length by species`
# - x축 라벨: `species` / y축 라벨: `mean petal_length`
# - 컬러: **`orchid`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 7. 그래프 분석
#
# 위 **기본·심화 그래프**를 보고 알 수 있는 점을 **2문장**으로 쓰시오.

# %% [markdown]
# ✏️ **답:** (여기를 더블클릭해 2문장으로 작성하세요)
